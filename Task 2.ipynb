# %%
import pandas as pd
import sklearn.linear_model as linear
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# # Multiple Linear Regression #

# %%
file = pd.read_excel("task 1.xlsx", sheet_name='Sheet1')

print(len(file))
# Out:
# 171

# %%
print(file.columns)
# Out:
# Index(['youtube', 'facebook', 'newspaper', 'sales'], dtype='object')

# %%
X = file.drop('sales', axis=1)
y = file[['sales']]

X_train, X_test, y_train, y_test = train_test_split(X,y , 
                                   test_size=0.20, 
                                   shuffle=True)

# %%
multiple_regression = linear.LinearRegression()
multiple_regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_prediction = multiple_regression.predict(X_test)
mse = mean_squared_error(y_test, y_prediction)
r2 = r2_score(y_test, y_prediction)

print(y_prediction)

print(f'mse : {mse}' )
print(f'r2 : {r2}')
# Out:
# [[11.05338112]
#  [11.77407075]
#  [12.7809534 ]
#  [18.25499335]
#  [10.38798012]
#  [22.04524475]
#  [ 6.29116322]
#  [20.13957378]
#  [ 7.25769329]
#  [13.11001954]
#  [20.52788123]
#  [24.36662941]
#  [ 7.77839914]
#  [16.48725797]
#  [12.56931439]
#  [13.68809035]
#  [22.28389571]
#  [29.171489  ]
#  [20.78584609]
#  [ 7.84888466]
#  [18.57940145]
#  [ 6.35416948]
#  [17.34995897]
#  [26.08373794]
#  [25.86376323]
#  [21.11322753]
#  [23.23658108]
#  [24.98401528]
#  [11.56972335]
#  [21.46495874]
#  [ 9.68293746]
#  [14.38111639]
#  [22.25927417]
#  [14.5953133 ]
#  [19.62269272]]
# mse : 3.151778683053995
# r2 : 0.9180567167745778

# %%
X_with_intercept = sm.add_constant(X_train) 
sm_model = sm.OLS(y_train, X_with_intercept).fit()
print(sm_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.893
# Method:                 Least Squares   F-statistic:                     378.4
# Date:                Fri, 05 Dec 2025   Prob (F-statistic):           1.29e-64
# Time:                        10:40:15   Log-Likelihood:                -289.91
# No. Observations:                 136   AIC:                             587.8
# Df Residuals:                     132   BIC:                             599.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.3656      0.462      7.289      0.000       2.452       4.279
# ...

# %% [markdown]
# ### YouTube (coef = 0.0456, p < 0.001) → Highly significant ###
# YouTube ads are a very strong and reliable driver of sales.
#
# ### Facebook (coef = 0.1929, p < 0.001) → Highly significant ###
# Facebook ads have an even stronger impact than YouTube—about 4× more powerful per unit of spending.
#
# ### Newspaper (coef = 0.0024, p = 0.733) → Not significant ###
# Newspaper advertising does not measurably increase sales.
# The company may be wasting budget on newspapers
# Cutting newspaper spending probably won’t hurt sales

# %% [markdown]
# #### Facebook is the strongest driver of sales ####
# Highest coefficient (0.1929),
# Extremely significant,
# Best return on investment (ROI),
#
# #### YouTube is also highly effective ####
# Strong significant effect,
# Good ROI,
# Should be maintained or increased,
#
# #### Newspaper advertising has no significant impact ####
# Coefficient near zero,
# p = 0.733 (not significant),
# Company should consider reducing or eliminating newspaper budget,

# %% [markdown]
# # Logistic Regression #

# %%
X = file.drop(['sales', 'profitability'], axis=1)
y = file[['profitability']]

X_train, X_test, y_train, y_test = train_test_split(X,y , 
                                   test_size=0.20, 
                                   shuffle=True)

model = LogisticRegression()
model.fit(X_train, y_train)

y_prediction = model.predict(X_test)
mse = mean_squared_error(y_test, y_prediction)
r2 = r2_score(y_test, y_prediction)
# Out:
# C:\Users\hp probbok\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
accuracy = accuracy_score(y_test, y_prediction)
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", confusion_matrix(y_test, y_prediction))
print("Classification Report:\n", classification_report(y_test, y_prediction))
# Out:
# Accuracy: 0.8857142857142857
# Confusion Matrix:
#  [[15  3]
#  [ 1 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88        18
#            1       0.84      0.94      0.89        17
#
#     accuracy                           0.89        35
#    macro avg       0.89      0.89      0.89        35
# weighted avg       0.89      0.89      0.89        35
